# %% [markdown]
# # Redrob Candidate Ranker — Sandbox Demo
#
# Runs the ranking system end-to-end on a small pre-loaded candidate sample
# (`sample_input.jsonl`, 100 candidates) and produces a ranked CSV.
#
# CPU-only, no network during ranking, completes in seconds.
#
# **Setup:** replace `REPO_URL` below with your GitHub repository URL, then
# *Runtime → Run all*.

# %%
# 1) Fetch the code (skip if running locally with the files already present)
import os
REPO_URL = "https://github.com/YOUR_USERNAME/redrob-candidate-ranker"
if not os.path.exists("candidate_ranker"):
    # !git clone $REPO_URL repo
    # %cd repo

# %%
# 2) Install dependencies (scikit-learn / numpy / scipy)
# !pip install -q -r requirements.txt

# %%
# 3) Run the ranking pipeline on the pre-loaded 100-candidate sample
# !python rank.py --candidates ./sample_input.jsonl --out ./sample_ranking.csv

# %%
# 4) Show the ranked output
import pandas as pd
df = pd.read_csv("sample_ranking.csv")
print(f"{len(df)} candidates ranked")
df.head(20)

# %% [markdown]
# To rank a different sample, upload your own `*.jsonl` (≤100 candidates,
# same schema) and change the `--candidates` path in step 3.
